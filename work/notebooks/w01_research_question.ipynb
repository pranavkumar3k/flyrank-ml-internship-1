# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pranavkumar3k/flyrank-ml-internship-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane:Refresh / Content Opportunity Scoring
# Reason:Very practical and business-oriented.
# Naturally produces a ranked list of pages that deserve attention.
# Easy to frame as data → decision → action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: A content or SEO team can use the analysis to decide which pages should be reviewed or refreshed first.
#
# Action: The team could investigate the highest-ranked pages and decide whether to update their content, structure, or other relevant elements.
#
# Cost of a wrong call: A false positive could waste time and resources refreshing a page that did not need attention. A false negative could cause a potentially valuable page to be overlooked.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/pranavkumar3k/flyrank-ml-internship-1/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Median days since last update:", df["days_since_last_update"].median())
print("Median content age:", df["content_age_days"].median())
print("Median CTR:", df["ctr"].median())
# Out:
# Rows: 30000
# Columns: 44
# Median days since last update: 20.0
# Median content age: 236.0
# Median CTR: 0.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim:
# This work can identify observed patterns and rank pages based on measurable signals in the available data. The output should be treated as directional decision-support that can help prioritize pages for human review.
#
# What I cannot claim:
# The analysis cannot establish that refreshing a page will cause better performance, and it cannot prove that a particular page will improve after a recommendation. The ranking is not causal proof or a guarantee of future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
